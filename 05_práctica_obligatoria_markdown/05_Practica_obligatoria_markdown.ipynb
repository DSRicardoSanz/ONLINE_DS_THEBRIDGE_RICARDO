# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Markdown Práctica Obligatoria
#
# ## Ejercicio 1
# Vamos a aplicar los conocimientos adquiridos en este notebook, intentando reproducir la siguiente imagen en una celda markdown con su sintaxis. En el link va la página: https://www.kaggle.com/
#
# **TIP**: en [este enlace](https://www.markdownguide.org/basic-syntax/) tienes más ejemplos, por si te atascas con algo :)

# %% [markdown]
# ![imagen](./img/practica_obligatoria_markdown.png)

# %% [markdown]
# #### Aptitudes de data science
#
# **Lo más importante**
# * Matemáticas
# * Python
# * SQL
#
# <img src="attachment:8115cf74-0f05-4c58-8e55-ed8a84e57ebc.png" width = 150>
#
# Otro tema importante es el *Business Intelligence*
#
# Si tienes dudas, puedes escribirme a: <jaime.gonzalez@thebridgeschool.es>
#
# Y en esta página se aprende mucho de machine learning: [página de ML](https://www.thebridge.tech/bootcamps/data-science)

# %% [markdown]
# ## Ejercicio 2
# Para este ejercicio vas a crear dos nuevos elementos que no hemos visto en la teoría, tendrás que buscar en google cómo hacer: una tabla y una fórmula. Busca en la web la sintaxis y replica ambos elementos.(no es necesaria la tira azul)

# %% [markdown]
# <div style="text-align:center"><img src="./img/md_ejercicio2.png" /></div>

# %% [markdown]
# |  **Ramp Up**  |  **Data Analysis**  |  **Machine Learning**  | **Data & Business**  |
# |:--------------|:--------------------|:-----------------------|:---------------------|
# |Python         |EDA                  |Supervised              |Productivización      |
# |Estadística    |R                    |Non supervised          |Storytelling          |
# |SQL            | Feat. Eng.          |Deep Learning           |API                   |

# %% [markdown]
# $$\sqrt{3x-1}+(1+x)^2$$
